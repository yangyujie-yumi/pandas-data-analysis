# %%
import pandas as pd
import numpy as np

# %%
position=pd.read_csv("position.csv")

# %%
company=pd.read_csv("company.csv",encoding="gbk")

# %%
position
# Out:
#      city  companyId                     名称  \
# 0      上海      23177       上海点荣金融信息服务有限责任公司
# 1      上海      57561         上海晶樵网络信息技术有限公司
# 2      上海       7502      杭州数云信息技术有限公司上海分公司
# 3      上海      57577           上海清源绿网科技有限公司
# 4      上海      93141        上海融之家金融信息服务有限公司
# 5      上海     143807           上海远目投资管理有限公司
# 6      上海      73539           北京数字新思科技有限公司
# 7      上海     146592             上海甫田贸易有限公司
# 8      上海       7069           伽蓝（集团）股份有限公司
# 9      上海      25499         路通世纪(中国)科技有限公司
# 10     上海      47063  中国四达国际经济技术合作有限公司上海分公司
# 11     上海     113080             银联数据服务有限公司
# 12     上海      23177       上海点荣金融信息服务有限责任公司
# 13     上海       7502      杭州数云信息技术有限公司上海分公司
# 14     上海       2002           上海好体信息科技有限公司
# 15     上海       7502      杭州数云信息技术有限公司上海分公司
# 16     上海      25499         路通世纪(中国)科技有限公司
# 17     上海      35713            德佑房地产经纪有限公司
# 18     上海      47993           上海网鱼信息科技有限公司
# 19     上海      55581          上海链家房地产经纪有限公司
# ...

# %%
position.groupby("city").mean()
# Out:
#          companyId    positionId         平均  Unnamed: 18
# city
# 上海    59085.843361  2.154012e+06  12.975104          NaN
# 北京    54668.078765  2.202001e+06  13.638257          NaN
# 南京    63834.506024  2.259256e+06   8.036145          NaN
# 厦门    65063.166667  1.950048e+06   7.700000          NaN
# 天津    72552.350000  2.221607e+06   6.300000          NaN
# 广州    60209.665672  2.216608e+06   9.397015          NaN
# 成都    72342.822222  2.202573e+06   9.474074          NaN
# 杭州    52299.164619  2.193057e+06  11.874693          NaN
# 武汉    59865.057971  2.123315e+06   8.101449          NaN
# 深圳    59497.745731  2.136640e+06  12.825427          NaN
# 苏州    47339.459459  2.141410e+06  10.594595          NaN
# 西安    72292.450980  2.187909e+06   7.431373          NaN
# 长沙    56073.040000  2.130448e+06   6.960000          NaN

# %%
position.groupby("city").agg("mean")
# Out:
#          companyId    positionId         平均  Unnamed: 18
# city
# 上海    59085.843361  2.154012e+06  12.975104          NaN
# 北京    54668.078765  2.202001e+06  13.638257          NaN
# 南京    63834.506024  2.259256e+06   8.036145          NaN
# 厦门    65063.166667  1.950048e+06   7.700000          NaN
# 天津    72552.350000  2.221607e+06   6.300000          NaN
# 广州    60209.665672  2.216608e+06   9.397015          NaN
# 成都    72342.822222  2.202573e+06   9.474074          NaN
# 杭州    52299.164619  2.193057e+06  11.874693          NaN
# 武汉    59865.057971  2.123315e+06   8.101449          NaN
# 深圳    59497.745731  2.136640e+06  12.825427          NaN
# 苏州    47339.459459  2.141410e+06  10.594595          NaN
# 西安    72292.450980  2.187909e+06   7.431373          NaN
# 长沙    56073.040000  2.130448e+06   6.960000          NaN

# %%
position.pivot_table(index=["city","education"],columns="workYear",values="平均",aggfunc=np.mean).loc["上海"]
# Out:
# workYear        1-3年  10年以上  1年以下       3-5年      5-10年         不限     应届毕业生
# education
# 不限          9.388889   30.0   5.0  10.833333  13.333333   9.718750       NaN
# 博士          9.000000    NaN   NaN        NaN        NaN  15.000000       NaN
# 大专          8.000000    NaN   3.5  13.066667  16.000000   4.166667  4.000000
# 本科         10.529661   32.5   8.0  15.282528  20.631579   7.106061  6.142857
# 硕士         10.652174   15.0   5.0  14.533333  30.214286   7.000000  6.500000
