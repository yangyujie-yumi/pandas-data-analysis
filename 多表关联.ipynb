# %%
import pandas as pd
import numpy as np

# %%
position=pd.read_csv("position.csv")

# %%
company=pd.read_csv("company.csv",encoding="gbk")

# %%
position
# Out:
#      city  companyId                     名称  \
# 0      上海      23177       上海点荣金融信息服务有限责任公司
# 1      上海      57561         上海晶樵网络信息技术有限公司
# 2      上海       7502      杭州数云信息技术有限公司上海分公司
# 3      上海      57577           上海清源绿网科技有限公司
# 4      上海      93141        上海融之家金融信息服务有限公司
# 5      上海     143807           上海远目投资管理有限公司
# 6      上海      73539           北京数字新思科技有限公司
# 7      上海     146592             上海甫田贸易有限公司
# 8      上海       7069           伽蓝（集团）股份有限公司
# 9      上海      25499         路通世纪(中国)科技有限公司
# 10     上海      47063  中国四达国际经济技术合作有限公司上海分公司
# 11     上海     113080             银联数据服务有限公司
# 12     上海      23177       上海点荣金融信息服务有限责任公司
# 13     上海       7502      杭州数云信息技术有限公司上海分公司
# 14     上海       2002           上海好体信息科技有限公司
# 15     上海       7502      杭州数云信息技术有限公司上海分公司
# 16     上海      25499         路通世纪(中国)科技有限公司
# 17     上海      35713            德佑房地产经纪有限公司
# 18     上海      47993           上海网鱼信息科技有限公司
# 19     上海      55581          上海链家房地产经纪有限公司
# ...

# %%
position.groupby(["city","education"]).平均.mean()["上海"]["博士"]
# Out:
# 11.0

# %%
position.positionLables.str[1:-1].str.replace("'","")
# Out:
# 0                                     分析师, 数据分析, 数据挖掘, 数据
# 1                                           分析师, 数据分析, 数据
# 2                                        商业, 分析师, 大数据, 数据
# 3                                                     分析师
# 4                                                      数据
# 5                                                     分析师
# 6                                        商业, 数据分析, 数据, BI
# 7                                            数据分析, 仓储, 数据
# 8                                        商业, 数据分析, 数据, BI
# 9                                             商业, 分析师, 品牌
# 10                                                     数据
# 11                                          招聘, 高校, C, 数据
# 12                                                 数据, 系统
# 13                                          商业, 分析师, 需求分析
# 14                                                     数据
# 15                                            大数据, 数据, 算法
# ...

# %%
position[position.city=="上海"]["city"]=np.NAN
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
position.loc[position.city=="上海","city"]=np.NAN

# %%
position
# Out:
#      city  companyId                     名称  \
# 0     NaN      23177       上海点荣金融信息服务有限责任公司
# 1     NaN      57561         上海晶樵网络信息技术有限公司
# 2     NaN       7502      杭州数云信息技术有限公司上海分公司
# 3     NaN      57577           上海清源绿网科技有限公司
# 4     NaN      93141        上海融之家金融信息服务有限公司
# 5     NaN     143807           上海远目投资管理有限公司
# 6     NaN      73539           北京数字新思科技有限公司
# 7     NaN     146592             上海甫田贸易有限公司
# 8     NaN       7069           伽蓝（集团）股份有限公司
# 9     NaN      25499         路通世纪(中国)科技有限公司
# 10    NaN      47063  中国四达国际经济技术合作有限公司上海分公司
# 11    NaN     113080             银联数据服务有限公司
# 12    NaN      23177       上海点荣金融信息服务有限责任公司
# 13    NaN       7502      杭州数云信息技术有限公司上海分公司
# 14    NaN       2002           上海好体信息科技有限公司
# 15    NaN       7502      杭州数云信息技术有限公司上海分公司
# 16    NaN      25499         路通世纪(中国)科技有限公司
# 17    NaN      35713            德佑房地产经纪有限公司
# 18    NaN      47993           上海网鱼信息科技有限公司
# 19    NaN      55581          上海链家房地产经纪有限公司
# ...

# %%
position=position.fillna("上海")

# %%
position
# Out:
#      city  companyId                     名称  \
# 0      上海      23177       上海点荣金融信息服务有限责任公司
# 1      上海      57561         上海晶樵网络信息技术有限公司
# 2      上海       7502      杭州数云信息技术有限公司上海分公司
# 3      上海      57577           上海清源绿网科技有限公司
# 4      上海      93141        上海融之家金融信息服务有限公司
# 5      上海     143807           上海远目投资管理有限公司
# 6      上海      73539           北京数字新思科技有限公司
# 7      上海     146592             上海甫田贸易有限公司
# 8      上海       7069           伽蓝（集团）股份有限公司
# 9      上海      25499         路通世纪(中国)科技有限公司
# 10     上海      47063  中国四达国际经济技术合作有限公司上海分公司
# 11     上海     113080             银联数据服务有限公司
# 12     上海      23177       上海点荣金融信息服务有限责任公司
# 13     上海       7502      杭州数云信息技术有限公司上海分公司
# 14     上海       2002           上海好体信息科技有限公司
# 15     上海       7502      杭州数云信息技术有限公司上海分公司
# 16     上海      25499         路通世纪(中国)科技有限公司
# 17     上海      35713            德佑房地产经纪有限公司
# 18     上海      47993           上海网鱼信息科技有限公司
# 19     上海      55581          上海链家房地产经纪有限公司
# ...

# %%
position.groupby(by=["city","education"]).mean().loc[]
# Out:
# array([('上海', '不限'), ('上海', '博士'), ('上海', '大专'), ('上海', '本科'),
#        ('上海', '硕士'), ('北京', '不限'), ('北京', '博士'), ('北京', '大专'),
#        ('北京', '本科'), ('北京', '硕士'), ('南京', '不限'), ('南京', '大专'),
#        ('南京', '本科'), ('南京', '硕士'), ('厦门', '不限'), ('厦门', '大专'),
#        ('厦门', '本科'), ('厦门', '硕士'), ('天津', '不限'), ('天津', '大专'),
#        ('天津', '本科'), ('广州', '不限'), ('广州', '大专'), ('广州', '本科'),
#        ('广州', '硕士'), ('成都', '不限'), ('成都', '大专'), ('成都', '本科'),
#        ('成都', '硕士'), ('杭州', '不限'), ('杭州', '大专'), ('杭州', '本科'),
#        ('杭州', '硕士'), ('武汉', '不限'), ('武汉', '大专'), ('武汉', '本科'),
#        ('武汉', '硕士'), ('深圳', '不限'), ('深圳', '博士'), ('深圳', '大专'),
#        ('深圳', '本科'), ('深圳', '硕士'), ('苏州', '大专'), ('苏州', '本科'),
#        ('苏州', '硕士'), ('西安', '不限'), ('西安', '大专'), ('西安', '本科'),
#        ('西安', '硕士'), ('长沙', '不限'), ('长沙', '大专'), ('长沙', '本科'),
#        ('长沙', '硕士')], dtype=object)

# %%
position.index.values
# Out:
# array([   0,    1,    2, ..., 6857, 6858, 6859], dtype=int64)

# %%
position.loc[(position.city=="北京")&(position.education=="不限")]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-cb8665fa6d22> in <module>()
# ----> 1 position.loc[(city=="北京")&(position.education=="不限")]
#
# NameError: name 'city' is not defined

# %%
position[position.duplicated()]
# Out:
#      city  companyId                  名称  \
# 535    上海      40092  微额速达(上海)金融信息服务有限公司
# 4878   西安       7502   杭州数云信息技术有限公司上海分公司
# 4879   西安      59051       西安智行者信息技术有限公司
# 4880   西安     117203        西安亚购信息科技有限公司
# 4881   西安      33214        西安美林电子有限责任公司
# 4882   西安       4184     北京思特奇信息技术股份有限公司
# 4883   西安       4210      神州数码信息服务股份有限公司
# 4884   西安      83818        西安全景数据技术有限公司
# 4885   西安      88076     北京易讯通信息技术股份有限公司
# 4886   西安      83879        西安美齐电子商务有限公司
# 4887   西安     104805        西安长城数字软件有限公司
# 4888   西安      87928      西安远古信息科技股份有限公司
# 4889   西安     101076        海航生态科技集团有限公司
# 4890   西安     126320        西安比特教育科技有限公司
# 5028   北京      55446       链家网（北京）科技有限公司
# 5029   北京      29605        大公国际资信评估有限公司
# 5030   北京     142642  星宇恒达(北京)国际管理投资有限公司
# 5031   北京     142642  星宇恒达(北京)国际管理投资有限公司
# 5032   北京     142642  星宇恒达(北京)国际管理投资有限公司
# 5033   北京      55446       链家网（北京）科技有限公司
# 5034   北京      55446       链家网（北京）科技有限公司
# 5035   北京      56379          人民视讯文化有限公司
# ...

# %%
a=position.drop_duplicates()

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5020 entries, 0 to 6750
# Data columns (total 19 columns):
# city                 5020 non-null object
# companyId            5020 non-null int64
# 名称                   5020 non-null object
# companyLabelList     4519 non-null object
# companyShortName     5020 non-null object
# companySize          5020 non-null object
# businessZones        3524 non-null object
# firstType            5015 non-null object
# secondType           5016 non-null object
# education            5020 non-null object
# industryField        5020 non-null object
# positionId           5020 non-null int64
# positionAdvantage    5020 non-null object
# positionName         5020 non-null object
# positionLables       4996 non-null object
# salary               5020 non-null object
# 平均                   5020 non-null int64
# workYear             5020 non-null object
# Unnamed: 18          0 non-null float64
# dtypes: float64(1), int64(3), object(15)
# ...

# %%
df=pd.read_csv("E_Commerce_Data.csv")

# %%
df.apply(lambda x:x.isnull().sum()/len(x))
# Out:
# InvoiceNo      0.000000
# StockCode      0.000000
# Description    0.002683
# Quantity       0.000000
# InvoiceDate    0.000000
# UnitPrice      0.000000
# CustomerID     0.249267
# Country        0.000000
# dtype: float64
